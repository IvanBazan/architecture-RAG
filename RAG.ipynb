# %%
#загружаем класс клиента Phi3
#проверка простых вопросов к LLM
import sys
sys.path.append('./src') 
from simple_phi3 import Phi3Client

client = Phi3Client()
answer = client.ask("Is Ural mountains in Russia?")
print(answer)
# Out:
# Да, Урал есть горная система в России.
